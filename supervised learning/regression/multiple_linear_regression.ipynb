# %%
# !pip install plotly

# %%
from sklearn.datasets import make_regression
import pandas as pd
import numpy as np

import plotly.express as px
import plotly.graph_objects as go

from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
X, y = make_regression(
    n_samples=100, n_features=2, n_informative=2, n_targets=1, noise=50
)

# %%
df = pd.DataFrame({"feature1": X[:, 0], "feature2": X[:, 1], "target": y})

# %%
df.head()
# Out:
#    feature1  feature2     target
# 0  0.831416 -0.551677 -92.030753
# 1 -0.464522 -1.809484  80.981817
# 2  0.671211 -1.240507  -9.651879
# 3 -0.716529 -0.509638 -86.139315
# 4  0.858437 -1.157410  50.050575

# %%
df.shape
# Out:
# (100, 3)

# %%
# plotly to 3d graph
px.scatter_3d(df, x="feature1", y="feature2", z="target")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/.local/share/mise/installs/python/3.14.2/lib/python3.14/site-packages/IPython/core/formatters.py:984, in IPythonDisplayFormatter.__call__(self, obj)
#     982 method = get_real_method(obj, self.print_method)
#     983 if method is not None:
# --> 984     method()
#     985     return True
#
# File ~/.local/share/mise/installs/python/3.14.2/lib/python3.14/site-packages/plotly/basedatatypes.py:850, in BaseFigure._ipython_display_(self)
#     847 import plotly.io as pio
#     849 if pio.renderers.render_on_display and pio.renderers.default:
# --> 850     pio.show(self)
#     851 else:
#     852     print(repr(self))
#
# File ~/.local/share/mise/installs/python/3.14.2/lib/python3.14/site-packages/plotly/io/_renderers.py:415, in show(fig, renderer, validate, **kwargs)
#     410     raise ValueError(
# ...

# %%
# now from here goes the ml
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2)

# %%
# importing the model
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_prediction = model.predict(X_test)

# %%
print("MAE : ", mean_absolute_error(y_test, y_pred=y_prediction))
print("MSE : ", mean_squared_error(y_test, y_prediction))
print("R2 Score : ", r2_score(y_test, y_prediction))
# Out:
# MAE :  42.29333963120832
# MSE :  2618.661658615879
# R2 Score :  0.025101103623203613

# %% [markdown]
# ## Building my Own Multiple Linear Regression model from scratch

# %% [markdown]
# ### Mathematical formulation and coding for multiple lr
#
# formula for predection :
#
# ```y^ = beta0 + beta1 * x1 + beta2 * x2 + beta3 * x3```
#
# here we are finding the values of `beta's`
#
# and to calculate the `beta` the mathematical formulation is:
#
# ``` beta = (X^T X) ^ -1 X^T Y```
#
# X = Matrix (all the values of features columns)
# Y = Y (what we have to predict)

# %%
# importing datasets from sklearn
from sklearn.datasets import load_diabetes

# %%
X, y = load_diabetes(return_X_y=True)

# %%
X.shape
# Out:
# (442, 10)

# %%
y.shape
# Out:
# (442,)

# %% [markdown]
# ## using sklearn's linear regression

# %%
from sklearn.model_selection import train_test_split
# Out:
#   Cell In[21], line 1
#     from sklearn.model_selection imprt train_test_split
#                                  ^
# SyntaxError: invalid syntax

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2)

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (353, 10)
# (89, 10)

# %%
from sklearn.linear_model import LinearRegression

# %%
reg = LinearRegression()

# %%
reg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = reg.predict(X_test)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test, y_pred=y_pred)
# Out:
# 0.439933866156897

# %%
reg.coef_  # values of betas
# Out:
# array([  -9.15865318, -205.45432163,  516.69374454,  340.61999905,
#        -895.5520019 ,  561.22067904,  153.89310954,  126.73139688,
#         861.12700152,   52.42112238])

# %%
reg.intercept_  # this is the value of beta0
# Out:
# np.float64(151.88331005254167)

# %% [markdown]
# # Making my own LINEAR REGRESSION CLASS

# %%
class myLearningRegression:
    def __init__(self):
        self.coef_ = None
        self.intercept_ = None

    def fit(self, X_train, y_train):
        # adding that 1111 column to our x_train data set
        X_train = np.insert(X_train, 0, 1, axis=1)

        # calculate the coefs
        betas = np.linalg.inv(np.dot(X_train.T, X_train)).dot(X_train.T).dot(y_train)
        self.intercept_ = betas[0]
        self.coef_ = betas[1:]

    def predict(self, X_test):
        y_pred = np.dot(X_test, self.coef_) + self.intercept_
        return y_pred

# %%
lr = myLearningRegression()

# %%
lr.fit(X_train=X_train, y_train=y_train)

# %%
y_pred = lr.predict(X_test)
# Out:
# array([154.1213881 , 204.81835118, 124.93755353, 106.08950893,
#        258.5348576 , 256.3310074 , 118.75087616, 119.52440696,
#        101.50816735, 190.54048661, 141.70656811, 172.51883961,
#        174.33861649, 134.80942706, 294.13994537,  94.11798038,
#        211.97059795, 156.49579378, 134.21000428, 119.62664644,
#        148.87842251, 165.00873409, 151.10021038, 176.04063756,
#        133.27769647, 221.29555392, 197.17324941,  96.1577688 ,
#         50.26012711, 230.48580317, 242.06073866, 114.11129218,
#         67.07532417,  94.52943825, 201.21415375, 167.05136201,
#        159.881268  , 192.78746659, 114.49551325, 233.48234551,
#        140.82563045, 121.0680409 , 192.27480772, 191.12738845,
#        179.16865788, 148.34935601, 163.47414622, 276.81647884,
#        100.17926432, 164.10555298, 255.80762189, 136.9466204 ,
#        152.37503699, 107.92237882, 194.21924678,  77.34670792,
#        118.50482479,  68.38335763, 154.29258529, 162.48840259,
# ...

# %%
r2_score(y_test, y_pred=y_pred)
# Out:
# 0.439933866156897

# %%
lr.coef_
# Out:
# array([  -9.15865318, -205.45432163,  516.69374454,  340.61999905,
#        -895.5520019 ,  561.22067904,  153.89310954,  126.73139688,
#         861.12700152,   52.42112238])

# %%
lr.intercept_
# Out:
# np.float64(151.88331005254176)
